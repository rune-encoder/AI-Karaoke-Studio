# %%
test = [
    "I knock on the door",
    "I tap on the floor",
    "It's gloomy in my mind",
    "I scratch on the wall",
    "Too feeble to bawl",
    "All along the line",
    "I'm losing faith",
    "I'm losing faith",
    "Here in my darkness",
    "I'm losing faith",
    "I'm losing faith",
    "Is there somebody here",
    "Somebody listening",
    "Someone who cares",
    "And someone who tries",
    "Somebody out there",
    "Someone to hold me",
    "When the raven dies tonight",
    "Is there somebody here",
    "Somebody listening",
    "Someone to share the rest of my time",
    "Somebody out there",
    "Someone to hold me",
    "When the raven dies tonight",
    "Is there somebody here?",
    "Who hears what I hear",
    "Who fears what I fear",
    "And pulls a left-behind",
    "Who lulls me to sleep",
    "Dreamless and deep",
    "Who's sensitive and kind",
    "I'm losing myself",
    "I'm losing myself",
    "Here in my darkness",
    "I'm losing myself",
    "I'm losing myself",
    "Is there somebody here",
    "Somebody listening",
    "Someone who cares",
    "And someone who tries",
    "Somebody out there",
    "Someone to hold me",
    "When the raven dies tonight",
    "Is there somebody here",
    "Somebody listening",
    "Someone to share the rest of my time",
    "Somebody out there",
    "Someone to hold me",
    "When the raven dies tonight",
    "Is there somebody here?",
    "A rare soul to believe me",
    "A saviour to release me",
    "A guiding light to lead me",
    "Hello?",
    "Is there somebody here?",
    "Is there somebody here?",
    "Is there somebody here",
    "Somebody listening",
    "Someone who cares",
    "And someone who tries",
    "Somebody out there",
    "Someone to hold me",
    "When the raven dies tonight",
    "Is there somebody here",
    "Somebody listening",
    "Someone to share the rest of my time",
    "Somebody out there",
    "Someone to hold me",
    "When the raven dies tonight",
    "Is there somebody here?",
    "Is there somebody here?",
    "Is there somebody here?",
    "Is there somebody here?",
    "Is there somebody here?",
    "Somebody here?",
    "Is there somebody here",
    "Somebody listening?"
]

# %%
compress_test = [
    word for verse in test for word in verse.split()
]

len(compress_test)
# Out:
# 301

# %%
test_2 = [("word", 'I', "start", 31.04, "end", 32.08),
 ("word", 'knock', "start", 32.08, "end", 32.38),
 ("word", 'on', "start", 32.38, "end", 32.68),
 ("word", 'the', "start", 32.68, "end", 32.88),
 ("word", 'door', "start", 32.88, "end", 33.3),
 ("word", 'I', "start", 33.3, "end", 33.94),
 ("word", 'tap', "start", 33.94, "end", 34.4),
 ("word", 'on', "start", 34.4, "end", 34.68),
 ("word", 'the', "start", 34.68, "end", 34.88),
 ("word", 'floor', "start", 34.88, "end", 35.24),
 ("word", "It's", "start", 35.24, "end", 36.16),
 ("word", 'gloomy', "start", 36.16, "end", 36.8),
 ("word", 'in', "start", 36.8, "end", 37.22),
 ("word", 'my', "start", 37.22, "end", 37.66),
 ("word", 'mind', "start", 37.66, "end", 38.22),
 ("word", 'I', "start", 38.22, "end", 39.82),
 ("word", 'scratch', "start", 39.82, "end", 40.36),
 ("word", 'on', "start", 40.36, "end", 40.7),
 ("word", 'the', "start", 40.7, "end", 40.88),
 ("word", 'wall', "start", 40.88, "end", 41.28),
 ("word", 'Too', "start", 41.28, "end", 42.1),
 ("word", 'feeble', "start", 42.1, "end", 42.64),
 ("word", 'to', "start", 42.64, "end", 42.88),
 ("word", 'bawl', "start", 42.88, "end", 43.26),
 ("word", 'All', "start", 43.8, "end", 44.44),
 ("word", 'along', "start", 44.44, "end", 45.14),
 ("word", 'the', "start", 45.14, "end", 45.64),
 ("word", 'line', "start", 45.64, "end", 46.04),
 ("word", 'there', "start", 226.88, "end", 227.18),
 ("word", 'somebody', "start", 227.18, "end", 227.66),
 ("word", 'here', "start", 227.66, "end", 228.44),
 ("word", 'Somebody', "start", 212.84, "end", 214.5),
 ("word", 'listening', "start", 213.44, "end", 214.5),
 ("word", 'Someone', "start", 214.5, "end", 215.4),
 ("word", 'to', "start", 215.4, "end", 215.84),
 ("word", 'share', "start", 215.84, "end", 216.2),
 ("word", 'the', "start", 216.2, "end", 216.92),
 ("word", 'rest', "start", 216.92, "end", 217.24),
 ("word", 'of', "start", 217.24, "end", 217.48),
 ("word", 'my', "start", 217.48, "end", 217.74),
 ("word", 'time', "start", 217.74, "end", 218.3),
 ("word", 'Somebody', "start", 218.86, "end", 220.22),
 ("word", 'out', "start", 219.64, "end", 220.22),
 ("word", 'there', "start", 220.22, "end", 220.58),
 ("word", 'Someone', "start", 220.58, "end", 221.48),
 ("word", 'to', "start", 221.48, "end", 221.92),
 ("word", 'hold', "start", 221.92, "end", 222.26),
 ("word", 'me', "start", 222.26, "end", 222.5),
 ("word", 'When', "start", 223.24, "end", 223.84),
 ("word", 'the', "start", 223.84, "end", 224.12),
 ("word", 'raven', "start", 224.12, "end", 224.88),
 ("word", 'dies', "start", 224.88, "end", 225.2),
 ("word", 'tonight', "start", 225.2, "end", 225.88),
 ("word", 'Is', "start", 229.86, "end", 230.98),
 ("word", 'there', "start", 230.98, "end", 231.14),
 ("word", 'somebody', "start", 231.14, "end", 231.6),
 ("word", 'here', "start", 231.6, "end", 232.28),
 ("word", 'Is', "start", 232.28, "end", 234.88),
 ("word", 'there', "start", 234.88, "end", 235.12),
 ("word", 'somebody', "start", 235.12, "end", 235.66),
 ("word", 'here', "start", 235.66, "end", 236.36),
 ("word", 'Is', "start", 240.34, "end", 241.74),
 ("word", 'there', "start", 241.74, "end", 243.14),
 ("word", 'somebody', "start", 243.14, "end", 243.66),
 ("word", 'here', "start", 243.66, "end", 244.38),
 ("word", 'Is', "start", 245.04, "end", 245.74),
 ("word", 'there', "start", 245.74, "end", 247.12),
 ("word", 'somebody', "start", 247.12, "end", 247.6),
 ("word", 'here', "start", 247.6, "end", 248.26),
 ("word", 'Somebody', "start", 250.14, "end", 252.28) 
]

# %%
len(test_2)
# Out:
# 290

# %%
from modules.utilities import load_json
from pprint import pprint

file = r'C:\Users\chris\ai_karaoke_app\output\acb59db18c5612564488035a65131a78ef6461a4a49555dd59f78f131a01fc21\modified_ai_lyrics.json'
data = load_json(file)

pprint(data, sort_dicts=False)
# Out:
# [{'verse_number': 1,
#   'text': 'I knock on the door',
#   'start': 31.04,
#   'end': 33.3,
#   'words': [{'word': 'I', 'word_number': 1, 'start': 31.04, 'end': 32.08},
#             {'word': 'knock', 'word_number': 2, 'start': 32.08, 'end': 32.38},
#             {'word': 'on', 'word_number': 3, 'start': 32.38, 'end': 32.68},
#             {'word': 'the', 'word_number': 4, 'start': 32.68, 'end': 32.88},
#             {'word': 'door', 'word_number': 5, 'start': 32.88, 'end': 33.3}]},
#  {'verse_number': 2,
#   'text': 'I tap on the floor',
#   'start': 33.94,
#   'end': 35.24,
#   'words': [{'word': 'I', 'word_number': 1, 'start': 33.94, 'end': 34.4},
#             {'word': 'tap', 'word_number': 2, 'start': 33.94, 'end': 34.4},
#             {'word': 'on', 'word_number': 3, 'start': 34.4, 'end': 34.68},
#             {'word': 'the', 'word_number': 4, 'start': 34.68, 'end': 34.88},
#             {'word': 'floor', 'word_number': 5, 'start': 34.88, 'end': 35.24}]},
# ...

# %%
""" 
[{'verse_number': 1,
  'text': 'I knock on the door',
  'start': 31.04,
  'end': 33.3,
  'words': [{'word': 'I', 'word_number': 1, 'start': 31.04, 'end': 32.08},
            {'word': 'knock', 'word_number': 2, 'start': 32.08, 'end': 32.38},
            {'word': 'on', 'word_number': 3, 'start': 32.38, 'end': 32.68},
            {'word': 'the', 'word_number': 4, 'start': 32.68, 'end': 32.88},
            {'word': 'door', 'word_number': 5, 'start': 32.88, 'end': 33.3}]},
 {'verse_number': 2,
  'text': 'I tap on the floor',
  'start': 33.94,
  'end': 35.24,
  'words': [{'word': 'I', 'word_number': 1, 'start': 33.94, 'end': 34.4},
            {'word': 'tap', 'word_number': 2, 'start': 33.94, 'end': 34.4},
            {'word': 'on', 'word_number': 3, 'start': 34.4, 'end': 34.68},
            {'word': 'the', 'word_number': 4, 'start': 34.68, 'end': 34.88},
            {'word': 'floor', 'word_number': 5, 'start': 34.88, 'end': 35.24}]},
 {'verse_number': 3,
  'text': "It's gloomy in my mind",
  'start': 35.24,
  'end': 38.22,

"""
test = []
for verse in data:
    for word in verse['words']:
        print(word['word'])
        test.append(word['word'])
    print()

len(test)
# Out:
# I
# knock
# on
# the
# door
#
# I
# tap
# on
# the
# floor
#
# It's
# gloomy
# in
# my
# mind
#
# I
# scratch
# on
# the
# wall
#
# Too
# feeble
# to
# bawl
#
# All
# along
# the
# line
#
# I'm
# losing
# faith
#
# I'm
# losing
# faith
#
# Here
# in
# my
# darkness
#
# I'm
# losing
# faith
#
# I'm
# losing
# faith
#
# Is
# there
# somebody
# here?
#
# Somebody
# listening
#
# Someone
# who
# cares
#
# And
# someone
# who
# tries
#
# Somebody
# out
# there
#
# Someone
# to
# hold
# me
#
# When
# the
# raven
# dies
# tonight
#
# Is
# there
# somebody
# here
#
# Somebody
# listening
#
# Someone
# to
# share
# the
# rest
# of
# my
# time
#
# Somebody
# out
# there
#
# Someone
# to
# hold
# me
#
# When
# the
# raven
# dies
# tonight
#
# Is
# there
# somebody
# here?
#
# Who
# hears
# what
# I
# hear
#
# Who
# fears
# what
# I
# fear
#
# And
# pulls
# a
# left-behind
#
# Who
# lulls
# me
# to
# sleep
#
# Dreamless
# and
# deep
#
# Who's
# sensitive
# and
# kind
#
# I'm
# losing
# myself
#
# ...
